# %% [markdown]
# <a href="https://colab.research.google.com/github/vsanchez435/FUNPRO/blob/main/CLASE_3_ESCTRUCTURA_DE_SELECCION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##IF-ELIF-ELSE
# Una de las formas para representar un switch
# 1. Hay una o varias variables a
# evaluar
# 2. Hay tantas condiciones como
# "paticas"+1
# 3. La última evaluación es ninguna de las anteriores (else)
# 4. La primera patica siempre recibe el "if"
# 5. El resto de paticas recibe"elif"
#
#   Sintaxis
#
# if condición1:
# expresión 1
# elif condición2:
# expresión 2
# elif condición3:
# expresión 3

# %%
#Pasa o no la materia, dependiendo de promedio>3 y asistencia>80%
nota=float(input("Ingrese su promedio: "))
asistencia=int(input("Ingrese la cantidad de horas asistidas: "))
horas_totales=int(input("Ingrese la cantidad de horas totales de la clase: "))
if nota>=3 and asistencia>=horas_totales*.8:
  print(f"El estudiante pasó la materia con {nota} y asistió más del 80% de las clases.")
elif nota<3 and asistencia>horas_totales*.8:
  print(f"El estudiante pierde la materia con {nota} pero asistió a más del 80% de las clases.")
elif nota>=3 and asistencia<horas_totales*.8:
  print(f"El estudiante pasó la materia con {nota} pero pierde debido a inasistencias.")
else:
  print(f"El estudiante perdió la materia con {nota} y no asistió a las clases suficientes")
# Out:
# Ingrese su promedio: 5
# Ingrese la cantidad de horas asistidas: 8
# Ingrese la cantidad de horas totales de la clase: 10
# El estudiante pasó la materia con 5.0 y asistió más del 80% de las clases.

# %% [markdown]
# MATCH_CASE
# Otra forma de ver la estructura switch
# 1. Dentro del hexágono se coloca la variable a evaluar
# 2. Tantas "paticas" como valores pueda adoptar la variable
# 3. Opcional: se coloca else-->case_
#
# Sintaxis
#
# match variable:
#   case valor1: expresión 1
#   case valor2: expresión 2
#   case valorn: expresion n
#   case _: ninguna de las anteriores

# %%
#Programa que identifique si la letra ingresada es una vocal mayúscula, minúscula
letra=input("Ingrese una letra:")
match letra:
  case"a":print(f"{letra} es una vocal minúscula")
  case"e":print(f" {letra} es una vocal minúscula")
  case"i":print(f" {letra} es una vocal minúscula")
  case"o":print(f" {letra} es una vocal minúscula")
  case"u":print(f" {letra} es una vocal minúscula")
  case"A":print(f" {letra} es una vocal MAYÚSCULA")
  case"E":print(f" {letra} es una vocal MAYÚSCULA")
  case"I":print(f" {letra} es una vocal MAYÚSCULA")
  case"O":print(f" {letra} es una vocal MAYÚSCULA")
  case"U":print(f"{letra} es una vocal MAYÚSCULA")
  case _:print(f"{letra} no es una vocal")
# Out:
# Ingrese una letra:A
#  Aes una vocal MAYÚSCULA

# %%
#Programa que identifique si la letra ingresada es una vocal mayúscula, minúscula
letra=input("Ingrese una letra:")
if letra=="a"or"e"or"i"or"o"or"u"
  print(f"{letra}minuscula")
elif letra=="A"or"E"or"I"or"O"or"U"
  print(f"{letra}mayuscula")
else
  print(f"{letra}no es una vocal")
# Out:
#   File "/tmp/ipython-input-2443945959.py", line 3
#     if letra=="a"or"e"or"i"or"o"or"u"
#                                      ^
# SyntaxError: expected ':'

# %%
#sistema de riego
humedad_suelo=float(input("ingrese la humedad del suelo"))
prob_lluvia=float(input("ingrese la probabbilidad de lluvia"))
temp_c=float(input("ingrese la temperatura"))
hora=int(input("ingrese hora del dia"))
if humedad_suelo<35 and prob_lluvia<40:
 print("regar")
elif (hora>=11 and hora<=15) and temp_c>35:
 print("no regar para evitar evaporacion")
elif prob_lluvia>=70:
 print("nunca regar")
elif humedad_suelo==0 or prob_lluvia==0 or temp_c==0 or hora==0:
 print("error sensor")
else:
  print("no se pueden tomar decisiones")
# Out:
# ingrese la humedad del suelo33
# ingrese la probabbilidad de lluvia30
# ingrese la temperatura65
# ingrese hora del dia10
# regar

# %% [markdown]
# ![WhatsApp Image 2025-09-17 at 11.25.47 PM.jpeg](data:image/jpeg;base64,...)

# %%
#sistema de tarifacion de energia
kwh=float(input("ingrese kwh consumidos"))
estrato=float(input("ingrese  su estrato"))
dia_semana=str(input("ingrese si es dia festivo o dia entre semana"))
recargo=float
descuento=float
base=float
base=kwh*620
if estrato<=2:
 descuento=base*0.2
 print(f"tienes un descuento del{descuento}")
elif dia_semana==festivo and kwh>1000:
 recargo=kwh*800
 print(f"tienes un recargo adicional de{recargo}")
elif kwh>0 or estrato>6 or estrato<0:
 print("presentamos un error, programa una visita lo mas pronto posible")
# Out:
# ingrese kwh consumidos500
# ingrese  su estrato2
# ingrese si es dia festivo o dia entre semanadia entre semana
# tienes un descuento del62000.0

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)
