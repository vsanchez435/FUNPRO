# %% [markdown]
# <a href="https://colab.research.google.com/github/vsanchez435/FUNPRO/blob/main/ESTRUCTURAS_DE_SELECCION_EJERCICIO_GRUPAL_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
C=float(input("ingrese la calificación del examen:"))
if C>=3.2:
  print("Aprobó")
else:
  print("Reprobó")
# Out:
# ingrese la calificación del examen:4
# Aprobó

# %% [markdown]
# ![WhatsApp Image 2025-09-15 at 6.03.26 PM.jpeg](data:image/jpeg;base64,...)
