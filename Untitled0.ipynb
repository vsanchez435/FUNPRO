# %% [markdown]
# <a href="https://colab.research.google.com/github/vsanchez435/FUNPRO/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...))

# %%
def prom (notas > 3 )
n=int (input ("Ingrese la cantidad de notas: "))
notas=int (input ("Ingrese las notas: "))
notas=[]
suma_notas=0
cont_notas=0
men_tres=0
i=1
for nota in  a:
    if i <= a:
      if nota > 3:
        suma=suma+nota
        con_notas=con_notas+1
      else: men_tres=i+1
    i=con_notas+men_tres
else:
  prom=suma/con_notas
  print(f"El promedio es (promedio)")
# Out:
#   File "/tmp/ipython-input-3541278286.py", line 1
#     def prom (notas > 3 )
#                     ^
# SyntaxError: invalid syntax
