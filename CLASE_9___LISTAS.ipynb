# %% [markdown]
# <a href="https://colab.research.google.com/github/vsanchez435/FUNPRO/blob/main/CLASE_9___LISTAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LISTAS
#
# Son tipos de datos que cumplen con tres caracterícas
#
#   Finita: Se puede contar cuántos elementos tiene la lista.
#
#   Homogénea: Sólo almacena un dato en específico
#
#   Ordenada o index: sabemos qué dato ocupa cada posición
#
# #Lista vacía
# lista=[]
#
# # Manual:
# flores=["rosa","azucena","amapola","jazmín"]

# %%
n=10
s=0
m=0
for e in range(n):
  sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
  s=sueldo+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
  sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
  if sueldo>prom: m=m+1
print(f"{m} trabajadores ganan más que el promedio")

#Problema: Ejercicio sin memoria.

# %%
n=10
s=0
m=0
sueldo=[]
for e in range(n):
  sueldo.append(int(input(f"Ingrese el sueldo del trabajador {e+1}: ")))
  s=sueldo[e]+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
  if sueldo[e]>prom: m=m+1
print(f"{m} trabajadores ganan más que el promedio")

# %%
n=[]
for nota in range(1,6):
  n.append(float(input(f"Ingrese las notas {nota}: ")))
if n[0]<n[1]<n[2]<n[3]<n[4]:
  print(f"se va a eleminar la nota {n[0]}")
  n.remove(n[0])
elif n[1]<n[2]<n[3]<n[4]:
  print(f"se va a eleminar la nota {n[1]}")
  n.remove(n[1])
elif n[2]<n[3]<n[4]:
  print(f"se va a eleminar la nota {n[2]}")
  n.remove(n[2])
elif n[3]<n[4]:
  print(f"se va a eleminar la nota {n[3]}")
  n.remove(n[3])
else:
  print(f"se va a eliminar la nota {n[4]}")
  n.remove(n[4])

# %%
# forma 2
n=[2,3.0,4,5,0.2]
mini=5.0
for notas in range(5):
  if n[notas]<min:
    mini=n[notas]

# %%
a="hola, cómo estas?"
type(a)

# %%
len(a)#Es finita

# %%
a[5]

# %%
a.capitalize()#Poner la primera letra en mayúscula

# %%
a.lower() #PONER EN MINUSCULA

# %%
a.upper() #PONER EN MAYUSCULA

# %%
a.index("s")

# %%
a.count("s")  #cuantas veces se repite es elemento

# %%
# Quiero crear un programa que me imprima letra por letra
"""
comportamiento de un para cuando se usa con listas
for letra in lista:
  1. El para se repite la cantidad de vec es de elementos que tiene una lista
  2. La variable adopta el valor de cada elemento de la lista
"""

c=1
for letra in a:
  print(f"{c}.{letra}")
  c=c+1

# %%
for letra in range(len(a)):
  print(f"{letra+1}. {a[letra]}")

# %%
for letra in a:
  print(f"{a.index(letra)+1}.{letra}")

# %%
rosas=["amarilla","verde","blanca"]
rosas.pop(0)
rosas

# %%
a= "Hola, cómo estás"
resultado=""
for letra in range(len(a)):
  if a [letra]=="a": resultado=resultado+ "i"
  elif a [letra]=="e": resultado=resultado+ "o"
  elif a [letra]=="i": resultado=resultado+ "u"
  elif a [letra]=="o": resultado=resultado+ "a"
  elif a [letra]=="u": resultado=resultado+ "e"
  else: resultado=resultado+a[letra]
print(resultado)

# %%
#Por 1000xp: lograr que si entra gaki, salga hola
palabra=(input("Ingrese la palabra: "))
resultado=""
for letra in range(len(palabra)):
  if palabra [letra]=="g": resultado=resultado+ "h"
  elif palabra [letra]=="k": resultado=resultado+ "l"
  elif palabra [letra]=="l": resultado=resultado+ "m"
  elif palabra [letra]=="b": resultado=resultado+ "c"
  elif palabra [letra]=="c": resultado=resultado+ "d"
  elif palabra [letra]=="d": resultado=resultado+ "f"
  elif palabra [letra]=="f": resultado=resultado+ "g"
  elif palabra [letra]=="j": resultado=resultado+ "k"
  elif palabra [letra]=="m": resultado=resultado+ "n"
  elif palabra [letra]=="n": resultado=resultado+ "ñ"
  elif palabra [letra]=="ñ": resultado=resultado+ "p"
  elif palabra [letra]=="p": resultado=resultado+ "q"
  elif palabra [letra]=="q": resultado=resultado+ "r"
  elif palabra [letra]=="r": resultado=resultado+ "s"
  elif palabra [letra]=="s": resultado=resultado+ "t"
  elif palabra [letra]=="t": resultado=resultado+ "v"
  elif palabra [letra]=="v": resultado=resultado+ "w"
  elif palabra [letra]=="w": resultado=resultado+ "x"
  elif palabra [letra]=="x": resultado=resultado+ "y"
  elif palabra [letra]=="y": resultado=resultado+ "z"
  elif palabra [letra]=="z": resultado=resultado+ "b"
  elif palabra [letra]=="a": resultado=resultado+ "o"
  elif palabra [letra]=="e": resultado=resultado+ "u"
  elif palabra [letra]=="i": resultado=resultado+ "a"
  elif palabra [letra]=="o": resultado=resultado+ "e"
  elif palabra [letra]=="u": resultado=resultado+ "i"
  elif palabra [letra]=="é": resultado=resultado+ "ó"
  elif palabra [letra]=="á": resultado=resultado+ "í"
  elif palabra [letra]=="ó": resultado=resultado+ "á"
  elif palabra [letra]=="í": resultado=resultado+ "ú"
  elif palabra [letra]=="ú": resultado=resultado+ "é"
  else: resultado=resultado+palabra[letra]
print(resultado)

# %%
palabra=(input("Ingrese la palabra: "))
resultado=""
for letra in range(len(palabra)):
  if palabra [letra]=="h": resultado=resultado+ "g"
  elif palabra [letra]=="l": resultado=resultado+ "k"
  elif palabra [letra]=="c": resultado=resultado+ "b"
  elif palabra [letra]=="f": resultado=resultado+ "d"
  elif palabra [letra]=="g": resultado=resultado+ "f"
  elif palabra [letra]=="k": resultado=resultado+ "j"
  elif palabra [letra]=="n": resultado=resultado+ "m"
  elif palabra [letra]=="ñ": resultado=resultado+ "n"
  elif palabra [letra]=="p": resultado=resultado+ "ñ"
  elif palabra [letra]=="q": resultado=resultado+ "p"
  elif palabra [letra]=="r": resultado=resultado+ "q"
  elif palabra [letra]=="s": resultado=resultado+ "r"
  elif palabra [letra]=="t": resultado=resultado+ "s"
  elif palabra [letra]=="v": resultado=resultado+ "t"
  elif palabra [letra]=="w": resultado=resultado+ "v"
  elif palabra [letra]=="x": resultado=resultado+ "w"
  elif palabra [letra]=="y": resultado=resultado+ "x"
  elif palabra [letra]=="z": resultado=resultado+ "y"
  elif palabra [letra]=="b": resultado=resultado+ "z"
  elif palabra [letra]=="o": resultado=resultado+ "a"
  elif palabra [letra]=="u": resultado=resultado+ "e"
  elif palabra [letra]=="a": resultado=resultado+ "i"
  elif palabra [letra]=="e": resultado=resultado+ "o"
  elif palabra [letra]=="i": resultado=resultado+ "u"
  else: resultado=resultado+palabra[letra]
print(resultado)

# %%
len(palabra)
